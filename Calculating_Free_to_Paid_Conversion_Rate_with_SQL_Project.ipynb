# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

sns.set(font_scale=1.0)

df = pd.read_csv('free_to_paid_conversion_rate.csv')

# %%
df
# Out:
#        student_id date_registered first_date_watched first_date_purchased  \
# 0          255193      2021-12-01         2021-12-01                  NaN
# 1          255194      2021-12-01         2021-12-01                  NaN
# 2          255198      2021-12-01         2022-02-17                  NaN
# 3          255199      2021-12-01         2021-12-01                  NaN
# 4          255200      2021-12-01         2021-12-01                  NaN
# ...           ...             ...                ...                  ...
# 16589      290708      2022-09-14         2022-09-14                  NaN
# 16590      290709      2022-09-14         2022-09-14                  NaN
# 16591      290711      2022-09-14         2022-09-14                  NaN
# 16592      290712      2022-09-14         2022-09-14                  NaN
# 16593      290714      2022-09-14         2022-09-14                  NaN
#
#        days_diff_reg_watch  days_diff_watch_purch
# 0                        0                    NaN
# 1                        0                    NaN
# 2                       78                    NaN
# 3                        0                    NaN
# 4                        0                    NaN
# ...                    ...                    ...
# 16589                    0                    NaN
# 16590                    0                    NaN
# 16591                    0                    NaN
# 16592                    0                    NaN
# 16593                    0                    NaN
#
# [16594 rows x 6 columns]

# %%
diff_1 = df['days_diff_reg_watch']
diff_2 = df['days_diff_watch_purch'].dropna()

# %%
sns.kdeplot(data = diff_1)
# Out:
# <Axes: xlabel='days_diff_reg_watch', ylabel='Density'>

# %%
sns.kdeplot(data = diff_2)
# Out:
# <Axes: xlabel='days_diff_watch_purch', ylabel='Density'>

# %%
print(f'Mean:\t {diff_1.mean()}')
print(f'Median:\t {diff_1.median()}')
print(f'Mode:\t {list(diff_1.mode())[0]}')
# Out:
# Mean:	 4.099493792937206
# Median:	 0.0
# Mode:	 0

# %%
print(f'Mean:\t {diff_2.mean()}')
print(f'Median:\t {diff_2.median()}')
print(f'Mode:\t {list(diff_2.mode())[0]}')
# Out:
# Mean:	 26.70250896057348
# Median:	 0.0
# Mode:	 0.0
